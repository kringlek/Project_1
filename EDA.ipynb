# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_2014 = pd.read_csv('Resources/data.csv')
df_2016 = pd.read_csv('Resources/data_2.csv')
df_2017 = pd.read_csv('Resources/data_3.csv')
df_2018 = pd.read_csv('Resources/data_4.csv')
mental = pd.read_csv('Resources/mental.csv')

# %%
mental
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 10696  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10697  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10698  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10699  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10700  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %%
new_group = mental.groupby('Time Period Label')
new_df = new_group.count()
new_df
# Out:
#                              Indicator  Group  State  Subgroup  Phase  \
# Time Period Label
# Apr 14 - Apr 26, 2021              216    216    216       216    216
# Apr 23 - May 5, 2020               210    210    210       210    210
# Apr 27 - May 9, 2022               234    234    234       234    234
# Apr 28 - May 10, 2021              216    216    216       216    216
# Aug 18 - Aug 30, 2021              234    234    234       234    234
# Aug 19 - Aug 31, 2020              210    210    210       210    210
# Aug 4 - Aug 16, 2021               234    234    234       234    234
# Dec 1 - Dec 13, 2021               234    234    234       234    234
# Dec 22, 2020 - Jan 5, 2021          57     57     57        57     57
# Dec 29, 2021 - Jan 10, 2022        234    234    234       234    234
# Dec 9 - Dec 21, 2020               210    210    210       210    210
# Feb 17 - Mar 1, 2021               210    210    210       210    210
# ...
