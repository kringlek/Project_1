# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mental = pd.read_csv('Resources/mental.csv')
vaccine = pd.read_csv('Resources/vaccine.csv', low_memory=False)

# %%
mental
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 10696  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10697  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10698  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10699  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 10700  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
# ...

# %%
new_group = mental.groupby('Group')
new_df = new_group.count()
new_df
# Out:
#                             Indicator  State  Subgroup  Phase  Time Period  \
# Group
# By Age                           1134   1134      1134   1134         1134
# By Disability status              144    144       144    144          144
# By Education                      648    648       648    648          648
# By Gender identity                144    144       144    144          144
# By Race/Hispanic ethnicity        810    810       810    810          810
# By Sex                            324    324       324    324          324
# By Sexual orientation             144    144       144    144          144
# By State                         7191   7191      7191   7191         7191
# National Estimate                 162    162       162    162          162
#
#                             Time Period Label  Time Period Start Date  \
# Group
# By Age                                   1134                    1134
# ...

# %%
vaccine
# Out:
#                Date   FIPS  MMWR_week     Recip_County Recip_State  \
# 0        07/27/2022  05121         30  Randolph County          AR
# 1        07/27/2022  19197         30    Wright County          IA
# 2        07/27/2022  37017         30    Bladen County          NC
# 3        07/27/2022  44001         30   Bristol County          RI
# 4        07/27/2022  28047         30  Harrison County          MS
# ...             ...    ...        ...              ...         ...
# 1828171  12/13/2020  12129         51   Wakulla County          FL
# 1828172  12/13/2020  05103         51  Ouachita County          AR
# 1828173  12/13/2020  46007         51   Bennett County          SD
# 1828174  12/13/2020  21031         51    Butler County          KY
# 1828175  12/13/2020  19051         51     Davis County          IA
#
#          Completeness_pct  Administered_Dose1_Recip  \
# 0                    90.5                    9055.0
# 1                    97.4                    7825.0
# ...

# %%
vax_group = vaccine.groupby('Recip_State')
vax_df = vax_group.count()
vax_df
# Out:
#                Date    FIPS  MMWR_week  Recip_County  Completeness_pct  \
# Recip_State
# AK            16706   16706      16706         16706             16706
# AL            37872   37872      37872         37872             37872
# AR            42329   42329      42329         42329             42329
# AS              548     548        548           548               449
# AZ             8909    8909       8909          8909              8909
# CA            32860   32860      32860         32860             32068
# CO            36202   36202      36202         36202             36202
# CT             5010    5010       5010          5010              5010
# DC             1110    1110       1110          1110              1110
# DE             2225    2225       2225          2225              2225
# FL            37873   37873      37873         37873             37873
# FM              553     553        553           553               454
# ...

# %%
mental['Subgroup'].unique()
# Out:
# array(['United States', '18 - 29 years', '30 - 39 years', '40 - 49 years',
#        '50 - 59 years', '60 - 69 years', '70 - 79 years',
#        '80 years and above', 'Male', 'Female', 'Hispanic or Latino',
#        'Non-Hispanic White, single race',
#        'Non-Hispanic Black, single race',
#        'Non-Hispanic Asian, single race',
#        'Non-Hispanic, other races and multiple races',
#        'Less than a high school diploma', 'High school diploma or GED',
#        "Some college/Associate's degree", "Bachelor's degree or higher",
#        'Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
# ...

# %%
mental_trimmed = mental.loc[(mental['Group'] == 'By Age') | (mental['Group'] == 'By State')].reset_index(drop=True)

# %%
mental_trimmed
# Out:
#                                               Indicator     Group  \
# 0                       Symptoms of Depressive Disorder    By Age
# 1                       Symptoms of Depressive Disorder    By Age
# 2                       Symptoms of Depressive Disorder    By Age
# 3                       Symptoms of Depressive Disorder    By Age
# 4                       Symptoms of Depressive Disorder    By Age
# ...                                                 ...       ...
# 8320  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 8321  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 8322  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 8323  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 8324  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#               State       Subgroup Phase  Time Period      Time Period Label  \
# 0     United States  18 - 29 years     1            1   Apr 23 - May 5, 2020
# ...

# %%
vaccine
# Out:
#                Date   FIPS  MMWR_week     Recip_County Recip_State  \
# 0        07/27/2022  05121         30  Randolph County          AR
# 1        07/27/2022  19197         30    Wright County          IA
# 2        07/27/2022  37017         30    Bladen County          NC
# 3        07/27/2022  44001         30   Bristol County          RI
# 4        07/27/2022  28047         30  Harrison County          MS
# ...             ...    ...        ...              ...         ...
# 1828171  12/13/2020  12129         51   Wakulla County          FL
# 1828172  12/13/2020  05103         51  Ouachita County          AR
# 1828173  12/13/2020  46007         51   Bennett County          SD
# 1828174  12/13/2020  21031         51    Butler County          KY
# 1828175  12/13/2020  19051         51     Davis County          IA
#
#          Completeness_pct  Administered_Dose1_Recip  \
# 0                    90.5                    9055.0
# 1                    97.4                    7825.0
# ...

# %%
vaccine_trimmed = vaccine[vaccine[['Date', 'Recip_State', 'Recip_County', 'Completeness_pct']]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 vaccine_trimmed = vaccine[vaccine[['Date', 'Recip_State', 'Recip_County', 'Completeness_pct']]]
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py:3492, in DataFrame.__getitem__(self, key)
#    3490 # Do we have a (boolean) DataFrame?
#    3491 if isinstance(key, DataFrame):
# -> 3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
#
# File ~\anaconda3\envs\PythonData\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
# ...

# %%
vaccine_trimmed
