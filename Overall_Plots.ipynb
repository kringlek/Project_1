# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import csv

# %%
#Read in data from csv
gender = pd.read_csv('Resources/gender_data.csv')
sexual_orientation = pd.read_csv('Resources/sexual_orientation_data.csv')
# Out:
#          Unnamed: 0           Symptoms of Depression Bisexual Depression  \
# 0                 0  Symptoms of Depressive Disorder            Bisexual
# 1                 1  Symptoms of Depressive Disorder            Bisexual
# 2                 2  Symptoms of Depressive Disorder            Bisexual
# 3                 3  Symptoms of Depressive Disorder            Bisexual
# 4                 4  Symptoms of Depressive Disorder            Bisexual
# ...             ...                              ...                 ...
# 1048571     1048571  Symptoms of Depressive Disorder            Bisexual
# 1048572     1048572  Symptoms of Depressive Disorder            Bisexual
# 1048573     1048573  Symptoms of Depressive Disorder            Bisexual
# 1048574     1048574  Symptoms of Depressive Disorder            Bisexual
# 1048575     1048575  Symptoms of Depressive Disorder            Bisexual
#
#          Bisexual Depression Value  Gay Depression      Time Period Label  \
# ...

# %%
#Function for Scatter Plot
def scatter_plot(params):
    
    # Save the y_axis value
    y_axis  = params.get("y_axis")
    y_label  = params.get("y_label")
    #outfile = params.get("outfile")
    x_axis = params.get("x_axis")
    x_label = params.get("x_label")
    color = params.get("color")
    
    plt.scatter(x_axis, y_axis, marker="o")
            
    plt.title(f"{x_label} vs. {y_label}")
    plt.ylabel(f"{y_label}")
    plt.xlabel(f"{x_label}")
    plt.grid()

    #Output
    #plt.savefig(f"../output_data/{outfile}")

# %%
#Depression- Male vs Female
plt.scatter(x=gender["Time Period Start Date"],y=male["Value"], color = "red")
plt.scatter(x=female["Time Period Start Date"],y=female["Value"], color = "blue")
dates = male["Time Period Start Date"]
ticks = dates[0:len(dates):3]
plt.xticks(ticks,rotation = 45)
plt.legend(["Male","Female"],loc="best")
plt.title("Percent Exhibiting Depression Symptoms in Male vs Females")
plt.ylabel("Percent Exhibiting Depression symptoms")
plt.xlabel("Date")

# %%
#Plot Anxiety Male vs Female
plt.scatter(x=male["Time Period Start Date"],y=male["Value"], color = "red")
plt.scatter(x=female["Time Period Start Date"],y=female["Value"], color = "blue")
dates = male["Time Period Start Date"]
ticks = dates[0:len(dates):3]
plt.xticks(ticks,rotation = 45)
plt.legend(["Male","Female"],loc="best")
plt.title("Percent Exhibiting Depression Symptoms in Male vs Females")
plt.ylabel("Percent Exhibiting Depression symptoms")
plt.xlabel("Date")

# %%
#Plot Depression by Sexual Orientation
plt.scatter(x=gay["Time Period Start Date"],y=gay["Value"], color = "red")
plt.scatter(x=straight["Time Period Start Date"],y=straight["Value"], color = "blue")
plt.scatter(x=bisexual["Time Period Start Date"],y=bisexual["Value"], color = "pink")
dates = depression_sex_orientation["Time Period Start Date"]
ticks = dates[0:len(dates):3]
plt.xticks(ticks,rotation = 45)
plt.legend(["Gay or lesbian","Straight", "Bisexual"],loc="best")
plt.title("Percent Exhibiting Depression Symptoms by Sexual Orientation")
plt.ylabel("Percent Exhibiting Depression Symptoms")
plt.xlabel("Date")

# %%
#Plot Depression by Sexual Orientation
plt.scatter(x=gay_anxiety["Time Period Start Date"],y=gay_anxiety["Value"], color = "red")
plt.scatter(x=straight_anxiety["Time Period Start Date"],y=straight_anxiety["Value"], color = "blue")
plt.scatter(x=bisexual_anxiety["Time Period Start Date"],y=bisexual_anxiety["Value"], color = "pink")
dates = anxiety_sex_orientation["Time Period Start Date"]
ticks = dates[0:len(dates):3]
plt.xticks(ticks,rotation = 45)
plt.legend(["Gay or lesbian","Straight", "Bisexual"],loc="best")
plt.title("Percent Exhibiting Anxiety Symptoms by Sexual Orientation")
plt.ylabel("Percent Exhibiting Anxiety Symptoms")
plt.xlabel("Date")
